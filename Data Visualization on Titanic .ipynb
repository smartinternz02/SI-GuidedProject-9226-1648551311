# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
d = sns.load_dataset("Titanic")

# %%
d.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
d.shape
# Out:
# (891, 15)

# %%
d.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
# # Create a pie chart presenting the male/female proportion

# %%
import matplotlib.pyplot as plt

# %%
d.sex.value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='sex'>

# %% [markdown]
# # Create a scatterplot with the fare played and the age ,differ the plot color by gender

# %%
import seaborn as sns

# %%
sns.scatterplot(x='age' , y='fare', hue='sex' , data=d)
# Out:
# <AxesSubplot:xlabel='age', ylabel='fare'>

# %% [markdown]
# # How many people survived

# %%
d.survived.sum()
# Out:
# 342

# %% [markdown]
# # Create a histogram with the fare payed

# %%
import seaborn as sns

# %%
sns.histplot(d.fare)
# Out:
# <AxesSubplot:xlabel='fare', ylabel='Count'>

# %%
sns.distplot(d['survived'])
# Out:
# C:\Users\SAI SRI  BHOGADI\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='survived', ylabel='Density'>

# %%
sns.distplot(d['age'])
# Out:
# C:\Users\SAI SRI  BHOGADI\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
sns.jointplot(x='survived', y='fare',data=d)

# %%
sns.jointplot(x='survived', y='age',data=d)

# %%
sns.jointplot(x='survived', y='age',data=d,kind='hex')

# %%
sns.rugplot(d['age'])
# Out:
# <AxesSubplot:xlabel='age'>

# %%
sns.rugplot(d['age'])
sns.kdeplot(d['age'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
sns.barplot(x='survived',y='fare',hue='sex',data=d)
# Out:
# <AxesSubplot:xlabel='survived', ylabel='fare'>

# %%
sns.countplot(x='survived',data=d)
# Out:
# <AxesSubplot:xlabel='survived', ylabel='count'>

# %%
sns.boxplot(x='sex',y='pclass',data=d)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='pclass'>

# %%
sns.violinplot(x='age',y='survived',data=d)
# Out:
# <AxesSubplot:xlabel='age', ylabel='survived'>

# %%
sns.stripplot(x='survived',y='sex',data=d)
# Out:
# <AxesSubplot:xlabel='survived', ylabel='sex'>
